# %% [markdown]
# Cleaning data from https://www.kaggle.com/devinanzelmo/dota-2-matches

# %%
import pandas as pd
import numpy as np
import os

# %%
match = pd.read_csv("./data/match.csv")

# %%
match.head()
# Out:
#    match_id  start_time  duration  tower_status_radiant  tower_status_dire  \
# 0         0  1446750112      2375                  1982                  4
# 1         1  1446753078      2582                     0               1846
# 2         2  1446764586      2716                   256               1972
# 3         3  1446765723      3085                     4               1924
# 4         4  1446796385      1887                  2047                  0
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode  \
# 0                     3                       63                 1         22
# 1                    63                        0               221         22
# 2                    63                       48               190         22
# 3                    51                        3                40         22
# 4                     0                       63                58         22
#
# ...

# %%
os.listdir("./data")
# Out:
# ['ability_ids.csv',
#  'ability_upgrades.csv',
#  'chat.csv',
#  'cluster_regions.csv',
#  'hero_names.csv',
#  'item_ids.csv',
#  'match.csv',
#  'match_outcomes.csv',
#  'objectives.csv',
#  'patch_dates.csv',
#  'players.csv',
#  'player_ratings.csv',
#  'player_time.csv',
#  'purchase_log.csv',
#  'teamfights.csv',
#  'teamfights_players.csv',
#  'test_labels.csv',
#  'test_player.csv',
#  'yasp_sample.json']

# %%
for col in match:
    print(col)
# Out:
# match_id
# start_time
# duration
# tower_status_radiant
# tower_status_dire
# barracks_status_dire
# barracks_status_radiant
# first_blood_time
# game_mode
# radiant_win
# negative_votes
# positive_votes
# cluster

# %%
# Identify column names
# This prints out column names in each datafile

dataset_names = os.listdir("./data")
for datafile in dataset_names:
    while True:
        if datafile == "yasp_sample.json":
            continue
        else:
            dataset = pd.read_csv("./data/{}".format(datafile))
            print("dataset:{}".format(datafile), dataset.columns)
            print("\n")
            break
# Out:
# dataset:ability_ids.csv Index(['ability_id', 'ability_name'], dtype='object')
#
#
# dataset:ability_upgrades.csv Index(['ability', 'level', 'time', 'player_slot', 'match_id'], dtype='object')
#
#
# dataset:chat.csv Index(['match_id', 'key', 'slot', 'time', 'unit'], dtype='object')
#
#
# dataset:cluster_regions.csv Index(['cluster', 'region'], dtype='object')
#
#
# dataset:hero_names.csv Index(['name', 'hero_id', 'localized_name'], dtype='object')
#
#
# dataset:item_ids.csv Index(['item_id', 'item_name'], dtype='object')
#
#
# dataset:match.csv Index(['match_id', 'start_time', 'duration', 'tower_status_radiant',
#        'tower_status_dire', 'barracks_status_dire', 'barracks_status_radiant',
#        'first_blood_time', 'game_mode', 'radiant_win', 'negative_votes',
#        'positive_votes', 'cluster'],
#       dtype='object')
#
#
# dataset:match_outcomes.csv Index(['match_id', 'account_id_0', 'account_id_1', 'account_id_2',
# ...

# %%
# Examining hero_names.csv
# This datafile maps hero_id's to hero names

heroes = pd.read_csv("./data/hero_names.csv")
heroes.head()
# Out:
#                            name  hero_id  localized_name
# 0        npc_dota_hero_antimage        1       Anti-Mage
# 1             npc_dota_hero_axe        2             Axe
# 2            npc_dota_hero_bane        3            Bane
# 3     npc_dota_hero_bloodseeker        4     Bloodseeker
# 4  npc_dota_hero_crystal_maiden        5  Crystal Maiden

# %%
# players.csv determine team, heroes and players for each match
players = pd.read_csv("./data/players.csv")
players[:10]
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
# 5         0           4      106          128   476       12285           397
# 6         0           0      102          129   317       10355           303
# 7         0           5       46          130  2390       13395           452
# 8         0           0        7          131   475        5035           189
# 9         0           6       73          132    60       17550           496
#
#    xp_per_min  kills  deaths  ...  unit_order_glyph  \
# 0         362      9       3  ...               NaN
# ...

# %% [markdown]
# ## Plan
# hero_names: hero_id to name
#
# match: match_id to radiant_win
#
# players:
#     match_id to hero_id
#     playerslot maps players to team: 0-4 radiant, 128-132 dire
